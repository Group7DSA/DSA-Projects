# %%
def sum_even_testscores(arr):
  total = 0
  for testscores in arr:
    if testscores % 2 == 0:
     total += testscores
  return total

testscores = [26,49,98,87,62,75]
result = sum_even_testscores(testscores)
print('Sum of even numbers Test scores is: ',result)
# Out:
# Sum of even numbers Test scores is:  186
